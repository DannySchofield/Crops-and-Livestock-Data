# %%
import pandas as pd #most effective data anaysis library
import numpy as np #for mathematical and logical operations
import matplotlib.pyplot as plt #for data visualisation
# %matplotlib inline 
#used to include matplotlibs graphs in notebook
import seaborn as sns #used with matplotlib for increased detail

# %%
crops_livestock = pd.read_excel('C:\\Users\\HP\\Documents\\Python Data\\FAOSTAT_data_5-9-2022.xlsx')

# %%
#selecting rows based on conditions

options = ['tonnes']

crops_livestock_1 = crops_livestock[(crops_livestock['Year'] >= 1961) &
                                    crops_livestock['Unit'].isin(options)]

# %%
crops_livestock_1.head()
# Out:
#      Domain Code                        Domain  Area Code (FAO)      Area  \
# 1042         QCL  Crops and livestock products              216  Thailand
# 1043         QCL  Crops and livestock products              216  Thailand
# 1044         QCL  Crops and livestock products              216  Thailand
# 1045         QCL  Crops and livestock products              216  Thailand
# 1046         QCL  Crops and livestock products              216  Thailand
#
#       Element Code     Element  Item Code (FAO)        Item  Year Code  Year  \
# 1042          5510  Production              226  Areca nuts       1983  1983
# 1043          5510  Production              226  Areca nuts       1984  1984
# 1044          5510  Production              226  Areca nuts       1985  1985
# 1045          5510  Production              226  Areca nuts       1986  1986
# 1046          5510  Production              226  Areca nuts       1987  1987
#
#         Unit    Value Flag Flag Description
# ...

# %%
#Exporting sorted data to check through in excel
crops_livestock_1.to_csv(r'C:\\Users\\HP\\Documents\\Python Data\\Sorted.csv')

# %%
# deleting unnecessary columns
df=crops_livestock_1.drop(columns=['Domain Code', 'Domain', 'Area Code (FAO)', 'Area', 'Element Code', 'Element', 'Item Code (FAO)', 'Year Code', 'Unit', 'Flag', 'Flag Description'])

# %%
#df_new = df.rename(columns={'Yield (tonnes)': 'Value'})

# %%
df.rename(columns={'Value': 'Production (tonnes)'}, inplace=True)

# %%
df.head()
# Out:
#             Item  Year  Production (tonnes)
# 1042  Areca nuts  1983              15000.0
# 1043  Areca nuts  1984              15000.0
# 1044  Areca nuts  1985              18000.0
# 1045  Areca nuts  1986              14000.0
# 1046  Areca nuts  1987              12000.0

# %%
df.tail()
# Out:
#           Item  Year  Production (tonnes)
# 46014  Yoghurt  2015              14913.0
# 46015  Yoghurt  2016              14907.0
# 46016  Yoghurt  2017              14882.0
# 46017  Yoghurt  2018              14870.0
# 46018  Yoghurt  2019              14507.0

# %%
df.to_csv(r'C:\\Users\\HP\\Documents\\Python Data\\Sort.csv')

# %%
df_master = pd.read_excel('C:\\Users\\HP\\Documents\\Python Data\\masterset.xlsx')

# %%
df_master.head()
# Out:
#    Unnamed: 0  Unnamed: 1  Year  Mean Temperature (℃)     Maize  Beans, dry  \
# 0         NaN         NaN  1961                 26.14   598.276        40.5
# 1         NaN         NaN  1962                 26.18   665.429        53.7
# 2         NaN         NaN  1963                 25.88   857.743       116.0
# 3         NaN         NaN  1964                 26.42   935.100       110.2
# 4         NaN         NaN  1965                 26.09  1021.268       124.8
#
#    Coffee, green  Rice, paddy  Soybeans  Sugar cane  Meat, buffalo  \
# 0           0.06      10150.0      24.2      2000.0         126.50
# 1           0.06      11250.0      30.0      1980.0         134.09
# 2           0.06      12171.0      33.0      1695.0         136.62
# 3           0.06      11600.0      31.3      2387.0         139.15
# 4           0.12      11164.0      19.1      3913.0         141.68
#
#    Meat, cattle  Meat, chicken  Meat, duck  Meat, pig
# ...

# %%
df_master1=df_master.drop(columns=['Unnamed: 0', 'Unnamed: 1'])

# %%
df_master1.head()
# Out:
#    Year  Mean Temperature (℃)     Maize  Beans, dry  Coffee, green  \
# 0  1961                 26.14   598.276        40.5           0.06
# 1  1962                 26.18   665.429        53.7           0.06
# 2  1963                 25.88   857.743       116.0           0.06
# 3  1964                 26.42   935.100       110.2           0.06
# 4  1965                 26.09  1021.268       124.8           0.12
#
#    Rice, paddy  Soybeans  Sugar cane  Meat, buffalo  Meat, cattle  \
# 0      10150.0      24.2      2000.0         126.50          70.0
# 1      11250.0      30.0      1980.0         134.09          72.0
# 2      12171.0      33.0      1695.0         136.62          74.0
# 3      11600.0      31.3      2387.0         139.15          76.0
# 4      11164.0      19.1      3913.0         141.68          78.0
#
#    Meat, chicken  Meat, duck  Meat, pig
# 0           82.0        9.75    129.067
# 1           86.0       10.05    131.865
# 2           95.0       12.00    130.060
# ...

# %%
df_master1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  60 non-null     int64
#  1   Mean Temperature (℃)  60 non-null     float64
#  2   Maize                 60 non-null     float64
#  3   Beans, dry            60 non-null     float64
#  4   Coffee, green         60 non-null     float64
#  5   Rice, paddy           60 non-null     float64
#  6   Soybeans              60 non-null     float64
#  7   Sugar cane            60 non-null     float64
#  8   Meat, buffalo         60 non-null     float64
#  9   Meat, cattle          60 non-null     float64
#  10  Meat, chicken         60 non-null     float64
#  11  Meat, duck            60 non-null     float64
#  12  Meat, pig             60 non-null     float64
# dtypes: float64(12), int64(1)
# memory usage: 6.2 KB

# %%
df_master2 = df_master1.apply(pd.to_numeric)

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Mean Temperature (℃)'], 
          x='Year', 
          kind='line',
          figsize=(25,10),
          title='Annual Surface Temperature Increase of Thailand',
          ylabel='Mean Temperature (Degrees Celsius)',
          xlabel='Year')
plt.xlim(1960, 2020)
# Out:
# (1960.0, 2020.0)

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Maize'], 
          x='Year', 
          kind='line',
          figsize=(25,10),
          title='Annual Maize Production',
          ylabel='Production in tonnes (thousands)',
          xlabel='Year')

plt.xlim(1960, 2020)
# Out:
# (1960.0, 2020.0)

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Beans, dry'], 
          x='Year', 
          kind='line',
          figsize=(25,10),
          title='Annual Beans (dry) Production',
          ylabel='Production in tonnes (thousands)',
          xlabel='Year')

plt.xlim(1960, 2020)
# Out:
# (1960.0, 2020.0)

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Coffee, green'], 
          x='Year', 
          kind='line',
          figsize=(25,10),
          title='Annual Coffee Production',
          ylabel='Production in tonnes (thousands)',
          xlabel='Year')

plt.xlim(1960, 2020)
# Out:
# (1960.0, 2020.0)

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Rice, paddy'], 
          x='Year', 
          kind='line',
          figsize=(25,10),
          title='Annual Rice Production',
          ylabel='Production in tonnes (thousands)',
          xlabel='Year')

plt.xlim(1960, 2020)
# Out:
# (1960.0, 2020.0)

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Soybeans'], 
          x='Year', 
          kind='line',
          figsize=(25,10),
          title='Annual Soybeans Production',
          ylabel='Production in tonnes (thousands)',
          xlabel='Year')

plt.xlim(1960, 2020)
# Out:
# (1960.0, 2020.0)

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Meat, buffalo'], 
          x='Year', 
          kind='line',
          figsize=(25,10),
          title='Annual Buffalo Meat Production',
          ylabel='Production in tonnes (thousands)',
          xlabel='Year')

plt.xlim(1960, 2020)
# Out:
# (1960.0, 2020.0)

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Meat, cattle'], 
          x='Year', 
          kind='line',
          figsize=(25,10),
          title='Annual Cattle Meat Production',
          ylabel='Production in tonnes (thousands)',
          xlabel='Year')

plt.xlim(1960, 2020)
# Out:
# (1960.0, 2020.0)

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Meat, chicken'], 
          x='Year', 
          kind='line',
          figsize=(25,10),
          title='Annual Chicken Meat Production',
          ylabel='Production in tonnes (thousands)',
          xlabel='Year')

plt.xlim(1960, 2020)
# Out:
# (1960.0, 2020.0)

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Meat, duck'], 
          x='Year', 
          kind='line',
          figsize=(25,10),
          title='Annual Duck Meat Production',
          ylabel='Production in tonnes (thousands)',
          xlabel='Year')

plt.xlim(1960, 2020)
# Out:
# (1960.0, 2020.0)

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Meat, pig'], 
          x='Year', 
          kind='line',
          figsize=(25,10),
          title='Annual Pig Meat Production',
          ylabel='Production in tonnes (thousands)',
          xlabel='Year')

plt.xlim(1960, 2020)
# Out:
# (1960.0, 2020.0)

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Meat, pig'], 
          x='Mean Temperature (℃)', 
          kind='scatter',
          figsize=(25,10),
          title='Pig meat production and temperature increase',
          ylabel='Production in tonnes (thousands)',
          xlabel='Mean Temperature (Degrees Celsius)')
# Out:
# <AxesSubplot:title={'center':'Pig meat production and temperature increase'}, xlabel='Mean Temperature (Degrees Celsius)', ylabel='Production in tonnes (thousands)'>

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Meat, buffalo'], 
          x='Mean Temperature (℃)', 
          kind='scatter',
          figsize=(25,10),
          title='Buffalo meat production and temperature increase',
          ylabel='Production in tonnes (thousands)',
          xlabel='Mean Temperature (Degrees Celsius)')
# Out:
# <AxesSubplot:title={'center':'Buffalo meat production and temperature increase'}, xlabel='Mean Temperature (Degrees Celsius)', ylabel='Production in tonnes (thousands)'>

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Meat, chicken'], 
          x='Mean Temperature (℃)', 
          kind='scatter',
          figsize=(25,10),
          title='Chicken meat production and temperature increase',
          ylabel='Production in tonnes (thousands)',
          xlabel='Mean Temperature (Degrees Celsius)')
# Out:
# <AxesSubplot:title={'center':'Chicken meat production and temperature increase'}, xlabel='Mean Temperature (Degrees Celsius)', ylabel='Production in tonnes (thousands)'>

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Meat, duck'], 
          x='Mean Temperature (℃)', 
          kind='scatter',
          figsize=(25,10),
          title='Duck meat production and temperature increase',
          ylabel='Production in tonnes (thousands)',
          xlabel='Mean Temperature (Degrees Celsius)')
# Out:
# <AxesSubplot:title={'center':'Duck meat production and temperature increase'}, xlabel='Mean Temperature (Degrees Celsius)', ylabel='Production in tonnes (thousands)'>

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Meat, cattle'], 
          x='Mean Temperature (℃)', 
          kind='scatter',
          figsize=(25,10),
          title='Cattle meat production and temperature increase',
          ylabel='Production in tonnes (thousands)',
          xlabel='Mean Temperature (Degrees Celsius)')
# Out:
# <AxesSubplot:title={'center':'Cattle meat production and temperature increase'}, xlabel='Mean Temperature (Degrees Celsius)', ylabel='Production in tonnes (thousands)'>

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Maize'], 
          x='Mean Temperature (℃)', 
          kind='scatter',
          figsize=(25,10),
          title='Maize production and temperature increase',
          ylabel='Production in tonnes (thousands)',
          xlabel='Mean Temperature (Degrees Celsius)')
# Out:
# <AxesSubplot:title={'center':'Maize production and temperature increase'}, xlabel='Mean Temperature (Degrees Celsius)', ylabel='Production in tonnes (thousands)'>

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Beans, dry'], 
          x='Mean Temperature (℃)', 
          kind='scatter',
          figsize=(25,10),
          title='Beans (dry) production and temperature increase',
          ylabel='Production in tonnes (thousands)',
          xlabel='Mean Temperature (Degrees Celsius)')
# Out:
# <AxesSubplot:title={'center':'Beans (dry) production and temperature increase'}, xlabel='Mean Temperature (Degrees Celsius)', ylabel='Production in tonnes (thousands)'>

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Sugar cane'], 
          x='Mean Temperature (℃)', 
          kind='scatter',
          figsize=(25,10),
          title='Sugar cane production and temperature increase',
          ylabel='Production in tonnes (thousands)',
          xlabel='Mean Temperature (Degrees Celsius)')
# Out:
# <AxesSubplot:title={'center':'Sugar cane production and temperature increase'}, xlabel='Mean Temperature (Degrees Celsius)', ylabel='Production in tonnes (thousands)'>

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Coffee, green'], 
          x='Mean Temperature (℃)', 
          kind='scatter',
          figsize=(25,10),
          title='Coffee production and temperature increase',
          ylabel='Production in tonnes (thousands)',
          xlabel='Mean Temperature (Degrees Celsius)')
# Out:
# <AxesSubplot:title={'center':'Coffee production and temperature increase'}, xlabel='Mean Temperature (Degrees Celsius)', ylabel='Production in tonnes (thousands)'>

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Rice, paddy'], 
          x='Mean Temperature (℃)', 
          kind='scatter',
          figsize=(25,10),
          title='Rice production and temperature increase',
          ylabel='Production in tonnes (thousands)',
          xlabel='Mean Temperature (Degrees Celsius)')
# Out:
# <AxesSubplot:title={'center':'Rice production and temperature increase'}, xlabel='Mean Temperature (Degrees Celsius)', ylabel='Production in tonnes (thousands)'>

# %%
plt.rcParams.update({'font.size': 20})
df_master2.plot(y=['Soybeans'], 
          x='Mean Temperature (℃)', 
          kind='scatter',
          figsize=(25,10),
          title='Soybeans production and temperature increase',
          ylabel='Production in tonnes (thousands)',
          xlabel='Mean Temperature (Degrees Celsius)')
# Out:
# <AxesSubplot:title={'center':'Soybeans production and temperature increase'}, xlabel='Mean Temperature (Degrees Celsius)', ylabel='Production in tonnes (thousands)'>

# %% [markdown]
# ## Regression model

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
# %matplotlib inline

# %%
df_master2.describe()
# Out:
#               Year  Mean Temperature (℃)        Maize  Beans, dry  \
# count    60.000000             60.000000    60.000000   60.000000
# mean   1990.500000             26.679167  3439.058267  183.879633
# std      17.464249              0.473445  1344.251801   84.203709
# min    1961.000000             25.680000   598.276000   40.500000
# 25%    1975.750000             26.380000  2631.396250  108.400000
# 50%    1990.500000             26.665000  3904.275000  180.850000
# 75%    2005.250000             26.927500  4505.872500  252.754500
# max    2020.000000             27.660000  5069.143000  356.141000
#
#        Coffee, green   Rice, paddy    Soybeans     Sugar cane  Meat, buffalo  \
# count      60.000000     60.000000   60.000000      60.000000      60.000000
# mean       33.316933  22002.763150  190.568817   42783.641300     102.967083
# std        28.502266   8059.161458  162.781598   34485.964787      56.049160
# ...

# %% [markdown]
# ## Temperature and Maize production

# %%
X = df_master2['Mean Temperature (℃)'].values.reshape(-1,1)
y = df_master2['Maize'].values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X, Y)

print(f'Coefficients: {lin_reg.coef_}')
print(f'Intercept: {lin_reg.intercept_}')
print(f'R^2 score: {lin_reg.score(X, y)}')
# Out:
# Coefficients: [[1913.85169016]]
# Intercept: [-47620.90995031]
# R^2 score: 0.45435396586506127

# %%
import statsmodels.api as sm

X_constant = sm.add_constant(X)
lin_reg = sm.OLS(y,X_constant).fit()
lin_reg.summary()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:7: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import (to_datetime, Int64Index, DatetimeIndex, Period,
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.454
# Model:                            OLS   Adj. R-squared:                  0.445
# Method:                 Least Squares   F-statistic:                     48.30
# ...

# %%
# %config InlineBackend.figure_format ='retina'
import statsmodels.stats.api as sms
sns.set_style('darkgrid')
sns.mpl.rcParams['figure.figsize'] = (15.0, 9.0)

def linearity_test(model, y):
    
    fitted_vals = model.predict()
    resids = model.resid

    fig, ax = plt.subplots(1,2)
    
    sns.regplot(x=fitted_vals, y=y, lowess=True, ax=ax[0], line_kws={'color': 'red'})
    ax[0].set_title('Observed vs. Predicted Values', fontsize=16)
    ax[0].set(xlabel='Predicted', ylabel='Observed')

    sns.regplot(x=fitted_vals, y=resids, lowess=True, ax=ax[1], line_kws={'color': 'red'})
    ax[1].set_title('Residuals vs. Predicted Values', fontsize=16)
    ax[1].set(xlabel='Predicted', ylabel='Residuals')
    
linearity_test(lin_reg, y)

# %%
lin_reg.resid.mean()
# Out:
# 7.048583938740194e-12

# %% [markdown]
# ## Temperature and Rice production

# %%
X = df_master2['Mean Temperature (℃)'].values.reshape(-1,1)
y = df_master2['Rice, paddy'].values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X, Y)

print(f'Coefficients: {lin_reg.coef_}')
print(f'Intercept: {lin_reg.intercept_}')
print(f'R^2 score: {lin_reg.score(X, y)}')
# Out:
# Coefficients: [[1913.85169016]]
# Intercept: [-47620.90995031]
# R^2 score: -5.243671130203912

# %%
import statsmodels.api as sm

X_constant = sm.add_constant(X)
lin_reg = sm.OLS(y,X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.536
# Model:                            OLS   Adj. R-squared:                  0.528
# Method:                 Least Squares   F-statistic:                     67.10
# Date:                Thu, 11 Aug 2022   Prob (F-statistic):           2.93e-11
# Time:                        12:52:58   Log-Likelihood:                -601.25
# No. Observations:                  60   AIC:                             1206.
# Df Residuals:                      58   BIC:                             1211.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -3.106e+05   4.06e+04     -7.648      0.000   -3.92e+05   -2.29e+05
# ...

# %%
# %config InlineBackend.figure_format ='retina'
import statsmodels.stats.api as sms
sns.set_style('darkgrid')
sns.mpl.rcParams['figure.figsize'] = (15.0, 9.0)

def linearity_test(model, y):
    
    fitted_vals = model.predict()
    resids = model.resid

    fig, ax = plt.subplots(1,2)
    
    sns.regplot(x=fitted_vals, y=y, lowess=True, ax=ax[0], line_kws={'color': 'red'})
    ax[0].set_title('Observed vs. Predicted Values', fontsize=16)
    ax[0].set(xlabel='Predicted', ylabel='Observed')

    sns.regplot(x=fitted_vals, y=resids, lowess=True, ax=ax[1], line_kws={'color': 'red'})
    ax[1].set_title('Residuals vs. Predicted Values', fontsize=16)
    ax[1].set(xlabel='Predicted', ylabel='Residuals')
    
linearity_test(lin_reg, y)

# %%
lin_reg.resid.mean()
# Out:
# 1.4667117890591424e-10

# %% [markdown]
# ## Temperature and Chicken Production

# %%
X = df_master2['Mean Temperature (℃)'].values.reshape(-1,1)
y = df_master2['Meat, chicken'].values.reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

# %%
lin_reg = LinearRegression()
lin_reg.fit(X, Y)

print(f'Coefficients: {lin_reg.coef_}')
print(f'Intercept: {lin_reg.intercept_}')
print(f'R^2 score: {lin_reg.score(X, y)}')
# Out:
# Coefficients: [[1913.85169016]]
# Intercept: [-47620.90995031]
# R^2 score: -25.0657507599581

# %%
import statsmodels.api as sm

X_constant = sm.add_constant(X)
lin_reg = sm.OLS(y,X_constant).fit()
lin_reg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.628
# Model:                            OLS   Adj. R-squared:                  0.622
# Method:                 Least Squares   F-statistic:                     97.98
# Date:                Thu, 11 Aug 2022   Prob (F-statistic):           4.52e-14
# Time:                        12:24:19   Log-Likelihood:                -432.75
# No. Observations:                  60   AIC:                             869.5
# Df Residuals:                      58   BIC:                             873.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.349e+04   2449.034     -9.590      0.000   -2.84e+04   -1.86e+04
# ...

# %%
# %config InlineBackend.figure_format ='retina'
import statsmodels.stats.api as sms
sns.set_style('darkgrid')
sns.mpl.rcParams['figure.figsize'] = (15.0, 9.0)

def linearity_test(model, y):
    
    fitted_vals = model.predict()
    resids = model.resid

    fig, ax = plt.subplots(1,2)
    
    sns.regplot(x=fitted_vals, y=y, lowess=True, ax=ax[0], line_kws={'color': 'red'})
    ax[0].set_title('Observed vs. Predicted Values', fontsize=16)
    ax[0].set(xlabel='Predicted', ylabel='Observed')

    sns.regplot(x=fitted_vals, y=resids, lowess=True, ax=ax[1], line_kws={'color': 'red'})
    ax[1].set_title('Residuals vs. Predicted Values', fontsize=16)
    ax[1].set(xlabel='Predicted', ylabel='Residuals')
    
linearity_test(lin_reg, y)

# %%
lin_reg.resid.mean()
# Out:
# 3.0430176896819223e-12
